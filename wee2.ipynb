# %%
print("hellow")
# Out:
# hellow

# %%
x = "hii"
print(x)
# Out:
# hii

# %%
print(type(x))
# Out:
# <class 'str'>

# %%
x = "hii"
print(type(x))
# Out:
# <class 'str'>

# %%
x = 10
print(type(x))
# Out:
# <class 'int'>

# %%
x = 10.5
print(type(x))
# Out:
# <class 'float'>
